# %%
import main
testData = main.load_data()
testData
# Out:
# 20:35:58 Loading "data.pickle"
#              Status                                               Name  \
# PassengerId
# 892              -1                                   Kelly, Mr. James
# 893              -1                   Wilkes, Mrs. James (Ellen Needs)
# 894              -1                          Myles, Mr. Thomas Francis
# 895              -1                                   Wirz, Mr. Albert
# 896              -1       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897              -1                         Svensson, Mr. Johan Cervin
# 898              -1                               Connolly, Miss. Kate
# 899              -1                       Caldwell, Mr. Albert Francis
# 900              -1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901              -1                            Davies, Mr. John Samuel
# 902              -1                                   Ilieff, Mr. Ylio
# 903              -1                         Jones, Mr. Charles Cresson
# ...

# %%
main.pivot_discrete(testData, "Salutation")
# Out:
# Status           -1      0      1
# Salutation
# Capt            0.0    1.0    0.0
# Col             2.0    1.0    1.0
# Don             0.0    1.0    0.0
# Dona            1.0    0.0    0.0
# Dr              1.0    4.0    3.0
# Jonkheer        0.0    1.0    0.0
# Lady            0.0    0.0    1.0
# Major           0.0    1.0    1.0
# Master         21.0   17.0   23.0
# Miss           78.0   55.0  127.0
# Mlle            0.0    0.0    2.0
# Mme             0.0    0.0    1.0
# Mr            240.0  436.0   81.0
# Mrs            72.0   26.0   99.0
# Ms              1.0    0.0    1.0
# Rev             2.0    6.0    0.0
# Sir             0.0    0.0    1.0
# the Countess    0.0    0.0    1.0
